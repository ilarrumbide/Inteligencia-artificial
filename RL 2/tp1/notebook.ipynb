# %%
from schemas import StateSchema
from query_router_env import QueryRouterEnv
from train import train,plot_rewards
from evaluation import evaluate_agent, evaluate_fixed,show_policy

# %%
schema = StateSchema()
env    = QueryRouterEnv(schema=schema)

# %%
# 1) entrenamiento
agent, rewards = train(env, schema, episodes=2000)
# Out:
# Episode 100/2000 | reward(avg100) = 15.175 | ε = 0.050
# Episode 200/2000 | reward(avg100) = 19.015 | ε = 0.050
# Episode 300/2000 | reward(avg100) = 18.055 | ε = 0.050
# Episode 400/2000 | reward(avg100) = 17.354 | ε = 0.050
# Episode 500/2000 | reward(avg100) = 18.459 | ε = 0.050
# Episode 600/2000 | reward(avg100) = 19.151 | ε = 0.050
# Episode 700/2000 | reward(avg100) = 18.049 | ε = 0.050
# Episode 800/2000 | reward(avg100) = 17.706 | ε = 0.050
# Episode 900/2000 | reward(avg100) = 18.323 | ε = 0.050
# Episode 1000/2000 | reward(avg100) = 17.556 | ε = 0.050
# Episode 1100/2000 | reward(avg100) = 17.523 | ε = 0.050
# Episode 1200/2000 | reward(avg100) = 18.080 | ε = 0.050
# Episode 1300/2000 | reward(avg100) = 17.975 | ε = 0.050
# Episode 1400/2000 | reward(avg100) = 19.020 | ε = 0.050
# Episode 1500/2000 | reward(avg100) = 18.288 | ε = 0.050
# Episode 1600/2000 | reward(avg100) = 18.309 | ε = 0.050
# Episode 1700/2000 | reward(avg100) = 18.759 | ε = 0.050
# Episode 1800/2000 | reward(avg100) = 18.618 | ε = 0.050
# Episode 1900/2000 | reward(avg100) = 18.682 | ε = 0.050
# Episode 2000/2000 | reward(avg100) = 17.428 | ε = 0.050

# %%
plot_rewards(rewards)

# %%
mean_agent   = evaluate_agent(env, agent, schema, episodes=2_000)

# %%
mean_gpt4o   = evaluate_fixed(env, action_idx=1, episodes=2_000)

# %%
print(f"\nAverage reward (agent)   : {mean_agent: .3f}")
print(f"Average reward (GPT-4o)   : {mean_gpt4o: .3f}")
# Out:
# Average reward (agent)   :  21.887
# Average reward (GPT-4o)   :  10.385

# %%
import numpy as np
show_policy(agent, schema)
# Out:
# small  | tools 0  | resp short  -> gpt-3.5-16k
# small  | tools 0  | resp medium -> gpt-3.5-16k
# small  | tools 0  | resp long   -> gemini-32k
# small  | tools 1  | resp short  -> gpt-3.5-16k
# small  | tools 1  | resp medium -> gpt-3.5-16k
# small  | tools 1  | resp long   -> gemini-32k
# small  | tools 2  | resp short  -> gpt-3.5-16k
# small  | tools 2  | resp medium -> gpt-3.5-16k
# small  | tools 2  | resp long   -> gemini-32k
# small  | tools ≥3 | resp short  -> gemini-32k
# small  | tools ≥3 | resp medium -> gpt-3.5-16k
# small  | tools ≥3 | resp long   -> gemini-32k
# medium | tools 0  | resp short  -> gemini-32k
# medium | tools 0  | resp medium -> gemini-32k
# medium | tools 0  | resp long   -> gemini-32k
# medium | tools 1  | resp short  -> gemini-32k
# medium | tools 1  | resp medium -> gemini-32k
# medium | tools 1  | resp long   -> gemini-32k
# medium | tools 2  | resp short  -> gemini-32k
# medium | tools 2  | resp medium -> gemini-32k
# medium | tools 2  | resp long   -> gemini-32k
# medium | tools ≥3 | resp short  -> gpt-4o-128k
# medium | tools ≥3 | resp medium -> gemini-32k
# medium | tools ≥3 | resp long   -> gemini-32k
# large  | tools 0  | resp short  -> gpt-4o-128k
# large  | tools 0  | resp medium -> gpt-4o-128k
# large  | tools 0  | resp long   -> gpt-4o-128k
# large  | tools 1  | resp short  -> gpt-4o-128k
# large  | tools 1  | resp medium -> gpt-4o-128k
# large  | tools 1  | resp long   -> gpt-4o-128k
# large  | tools 2  | resp short  -> gpt-4o-128k
# large  | tools 2  | resp medium -> gpt-4o-128k
# large  | tools 2  | resp long   -> gpt-4o-128k
# large  | tools ≥3 | resp short  -> gpt-4o-128k
# large  | tools ≥3 | resp medium -> gpt-4o-128k
# large  | tools ≥3 | resp long   -> gpt-4o-128k
